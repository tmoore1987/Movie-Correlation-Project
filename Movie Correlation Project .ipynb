# %%
import pandas as pd
import seaborn as sns
import numpy as np


import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure


# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)  #adjusts configuration of plots

# %%
#import file
db = pd.read_csv(r"C:\Users\taylo\OneDrive\Documents\Jupyter Projects\movies.csv")

# %%
db.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#check for missing data

for col in db.columns:
    pct_missing = np.mean(db[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#drop columns with na
db= db.dropna()

# %%
#recheck
for col in db.columns:
    pct_missing = np.mean(db[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# data types

db.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Modify data types
db['budget'] = db['budget'].astype('int64')
db['gross'] = db['gross'].astype('int64')

db
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
db.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
db = db.copy()

# %%
#update the correct year

db['released'] = db['released'].astype(str)
db['correctyear'] = db['released'].str.extract(pat='([0-9]{4})')

# %%
db
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
#sort by gross

db = db.sort_values(by=['budget'], inplace=False, ascending=False)

# %%
#scroll through all data
#pd.set_option('display.max_rows', None)
db
# Out:
#                                           name   rating   genre  year  \
# 7445                         Avengers: Endgame    PG-13  Action  2019
# 7244                    Avengers: Infinity War    PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi    PG-13  Action  2017
# 7066                            Justice League    PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End    PG-13  Action  2007
# ...                                        ...      ...     ...   ...
# 2211                            The Living End  Unrated  Comedy  1992
# 5114                       Paranormal Activity        R  Horror  2007
# 4507                                    Primer    PG-13   Drama  2004
# 2093                               El Mariachi        R  Action  1992
# 3318                                 Following        R   Crime  1998
#
#                                released  score     votes           director  \
# ...

# %%
# Drop any duplicates

db.drop_duplicates()
# Out:
#                                           name   rating   genre  year  \
# 7445                         Avengers: Endgame    PG-13  Action  2019
# 7244                    Avengers: Infinity War    PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi    PG-13  Action  2017
# 7066                            Justice League    PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End    PG-13  Action  2007
# ...                                        ...      ...     ...   ...
# 2211                            The Living End  Unrated  Comedy  1992
# 5114                       Paranormal Activity        R  Horror  2007
# 4507                                    Primer    PG-13   Drama  2004
# 2093                               El Mariachi        R  Action  1992
# 3318                                 Following        R   Crime  1998
#
#                                released  score     votes           director  \
# ...

# %%
pd.reset_option('display.max_rows')
db
# Out:
#       name  rating  genre  year  released  score     votes  director  writer  \
# 7445   388       5      0  2019       137    8.4  903000.0       105     513
# 7244   389       5      0  2018       145    8.4  897000.0       105     513
# 7075  3644       5      0  2017       500    7.0  581000.0      1589    2487
# 7066  2124       5      0  2017      1996    6.1  418000.0      2057    1402
# 5060  2987       5      0  2007      1844    7.1  608000.0       674    2927
# ...    ...     ...    ...   ...       ...    ...       ...       ...     ...
# 2211  4395       8      4  1992       317    6.5    2900.0       685    1094
# 5114  2906       6      9  2007      2199    6.3  225000.0      1452    2292
# 4507  3062       5      6  2004      1860    6.9  101000.0      1768    2768
# 2093  1257       6      0  1992       781    6.9   64000.0      1668    2601
# 3318  1461       6      5  1998      2112    7.5   89000.0       317     516
#
# ...

# %% [markdown]
# Budget and company will have high correlation

# %%
# Scatter plot with budget vs gross

plt.scatter(x=db['budget'], y=db['gross'])
plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for Film')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
db.head()
# Out:
#                                           name rating   genre  year  \
# 7445                         Avengers: Endgame  PG-13  Action  2019
# 7244                    Avengers: Infinity War  PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi  PG-13  Action  2017
# 7066                            Justice League  PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End  PG-13  Action  2007
#
#                                released  score     votes        director  \
# 7445     April 26, 2019 (United States)    8.4  903000.0   Anthony Russo
# 7244     April 27, 2018 (United States)    8.4  897000.0   Anthony Russo
# 7075  December 15, 2017 (United States)    7.0  581000.0    Rian Johnson
# 7066  November 17, 2017 (United States)    6.1  418000.0     Zack Snyder
# 5060       May 25, 2007 (United States)    7.1  608000.0  Gore Verbinski
#
#                   writer               star        country     budget  \
# ...

# %%
# Plot budget vs gross using seaborn

sns.regplot(x= 'budget', y= 'gross', data= db, scatter_kws={'color':'red'}, line_kws={'color': 'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#correlation

db.corr()
# Out:
# C:\Users\taylo\AppData\Local\Temp\ipykernel_10364\2332762549.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   db.corr()
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
#High correlation between budget and gross

# %%
correlation_matrix = db.corr()

sns.heatmap(correlation_matrix, annot= True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')


plt.show()
# Out:
# C:\Users\taylo\AppData\Local\Temp\ipykernel_10364\2130946888.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = db.corr()

# %%
# Look at the company

db.head()
# Out:
#                                           name rating   genre  year  \
# 7445                         Avengers: Endgame  PG-13  Action  2019
# 7244                    Avengers: Infinity War  PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi  PG-13  Action  2017
# 7066                            Justice League  PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End  PG-13  Action  2007
#
#                                released  score     votes        director  \
# 7445     April 26, 2019 (United States)    8.4  903000.0   Anthony Russo
# 7244     April 27, 2018 (United States)    8.4  897000.0   Anthony Russo
# 7075  December 15, 2017 (United States)    7.0  581000.0    Rian Johnson
# 7066  November 17, 2017 (United States)    6.1  418000.0     Zack Snyder
# 5060       May 25, 2007 (United States)    7.1  608000.0  Gore Verbinski
#
#                   writer               star        country     budget  \
# ...

# %%
db_numerized = db

for col_name in db_numerized.columns:
    if(db_numerized[col_name].dtype == 'object'):
        db_numerized[col_name] = db_numerized[col_name].astype('category')
        db_numerized[col_name]= db_numerized[col_name].cat.codes
        
db_numerized
# Out:
#       name  rating  genre  year  released  score     votes  director  writer  \
# 7445   388       5      0  2019       137    8.4  903000.0       105     513
# 7244   389       5      0  2018       145    8.4  897000.0       105     513
# 7075  3644       5      0  2017       500    7.0  581000.0      1589    2487
# 7066  2124       5      0  2017      1996    6.1  418000.0      2057    1402
# 5060  2987       5      0  2007      1844    7.1  608000.0       674    2927
# ...    ...     ...    ...   ...       ...    ...       ...       ...     ...
# 2211  4395       8      4  1992       317    6.5    2900.0       685    1094
# 5114  2906       6      9  2007      2199    6.3  225000.0      1452    2292
# 4507  3062       5      6  2004      1860    6.9  101000.0      1768    2768
# 2093  1257       6      0  1992       781    6.9   64000.0      1668    2601
# 3318  1461       6      5  1998      2112    7.5   89000.0       317     516
#
# ...

# %%
db
# Out:
#       name  rating  genre  year  released  score     votes  director  writer  \
# 7445   388       5      0  2019       137    8.4  903000.0       105     513
# 7244   389       5      0  2018       145    8.4  897000.0       105     513
# 7075  3644       5      0  2017       500    7.0  581000.0      1589    2487
# 7066  2124       5      0  2017      1996    6.1  418000.0      2057    1402
# 5060  2987       5      0  2007      1844    7.1  608000.0       674    2927
# ...    ...     ...    ...   ...       ...    ...       ...       ...     ...
# 2211  4395       8      4  1992       317    6.5    2900.0       685    1094
# 5114  2906       6      9  2007      2199    6.3  225000.0      1452    2292
# 4507  3062       5      6  2004      1860    6.9  101000.0      1768    2768
# 2093  1257       6      0  1992       781    6.9   64000.0      1668    2601
# 3318  1461       6      5  1998      2112    7.5   89000.0       317     516
#
# ...

# %%
correlation_matrix = db_numerized.corr()

sns.heatmap(correlation_matrix, annot= True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')


plt.show()

# %%
db_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released    -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score        0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
correlation_mat = db_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#                               ...
# correctyear  budget         0.320312
#              gross          0.268721
#              company       -0.018806
#              runtime        0.075294
#              correctyear    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# gross        genre         -0.244101
# genre        gross         -0.244101
# rating       budget        -0.203946
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# correctyear  correctyear    1.000000
# Length: 256, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# gross        votes          0.614751
# votes        gross          0.614751
# gross        budget         0.740247
# budget       gross          0.740247
# year         correctyear    0.998726
# correctyear  year           0.998726
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# correctyear  correctyear    1.000000
# dtype: float64

# %%
# votes and budget have the higest correlation to gross earnings

# %%
#Company has low correlation
